# %% [markdown]
# <a href="https://colab.research.google.com/github/BelikMary/Data_Science_platform/blob/main/Belik_lab02_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2-2
#
# Выполнила: Белик Мария
# АДЭУ-211

# %% [markdown]
# ## 2.2.1: Reading and Writing Data
#
# Файл [grades.csv](grades.csv) представляет собой файл с именами учащихся и буквенными оценками:
#
# ```
# Alice; A
# Bob; B
# Robert; A
# Richard; C
# ```
#
# Записать данные из файла в массив. Добавьте средний балл учащегося в строку учащегося (A=4,B=3,C=2,D=1).
#
# Подсказка: функция [strip()](https://docs.python.org/3/library/stdtypes.html#str.strip) удаляет конечные пробелы из строки.
#
# Запишите этот файл в новый файл `grades_gpa.csv`.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files                  #загрузка данных в колаб
uploaded = files.upload()

for fn in uploaded.keys():
  print('User upload file "{name}" witn length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-dbb9d3c8-e3d1-49f1-b461-ff715a03faaa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbb9d3c8-e3d1-49f1-b461-ff715a03faaa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Запись данных в массив:

grades_df02=pd.read_csv("grades.csv")
grades_df02=pd.concat([pd.DataFrame([grades_df02.columns.values], columns=grades_df02.columns), grades_df02], ignore_index=True) #настраиваем, чтобы первая строка была строкой, а не заголовками
grades_array02=grades_df02.to_numpy()


#Создание пустого списка:
e_a=[]


#Создание цикла, который в каждой строке i массива отделяет имя учащегося от его оценки в буквенном виде,
#затем по ключу получает значения из словаря gpas, который дан по условию, и записывает всё в пустой список.

for i in grades_array02:
  name, literal = i[0].split("; ")
  number=gpas.get(grade)
  e_a.append([name, literal, number])

#Получаем:

e_a
# Out:
# [['Alice', 'A', 4], ['Bob', 'B', 4], ['Robert', 'A', 4], ['Richard', 'C', 4]]

# %%
#Запись в csv файл:

grades_gpas_df02=pd.DataFrame(e_a)

grades_gpas_df02.to_csv('grades_gpas.csv', header=False, index=False)
print("Результат успешно записан в CSV файл 'grades_gpas.csv'")
# Out:
# Результат успешно записан в CSV файл 'grades_gpas.csv'

# %% [markdown]
# ## 2.2.2: Data Frames

# %%
from google.colab import files                  #загрузка данных в колаб
uploaded = files.upload()

for fn in uploaded.keys():
  print('User upload file "{name}" witn length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-76a6c676-d93b-4823-b9a7-804ed4719bf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76a6c676-d93b-4823-b9a7-804ed4719bf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
hit_albums = pd.read_csv("hit_albums.csv")
hit_albums
# Out:
#                                Artist  \
# 0                     Michael Jackson
# 1                               AC/DC
# 2                          Pink Floyd
# 3   Whitney Houston / Various artists
# 4                           Meat Loaf
# ..                                ...
# 72                      Tracy Chapman
# 73                              Usher
# 74                    Various artists
# 75                    Whitney Houston
# 76                            Shakira
#
#                                                 Album  Released  \
# 0                                            Thriller      1982
# 1                                       Back in Black      1980
# 2                           The Dark Side of the Moon      1973
# 3                                       The Bodyguard      1992
# 4                                     Bat Out of Hell      1977
# ..                                                ...       ...
# ...

# %% [markdown]
# * Рассчитайте средние сертифицированные продажи для всех альбомов.

# %%
sr=round(hit_albums['Certified sales (millions)'].mean(),1)
print("Средние сертифицированные продажи для всех альбомов: ", sr)
# Out:
# Средние сертифицированные продажи для всех альбомов:  22.4

# %% [markdown]
# * Создайте новый фрейм данных, содержащий только альбомы с сертифицированными продажами (более 20 миллионов человек купили альбом).

# %%
df1=hit_albums[['Album','Certified sales (millions)']].loc[(hit_albums['Certified sales (millions)']>20)]
df1=df1.sort_values(by='Certified sales (millions)', ascending=False)
df1
# Out:
#                                                 Album  \
# 0                                            Thriller
# 5                     Their Greatest Hits (1971–1975)
# 8                                        Come On Over
# 9                                     Led Zeppelin IV
# 31                                Gold: Greatest Hits
# 34  Grease: The Original Soundtrack from the Motio...
# 33                                              Spice
# 32                                  Slippery When Wet
# 35                              ...Baby One More Time
# 7                                             Rumours
# 3                                       The Bodyguard
# 36                                      Hybrid Theory
# 1                                       Back in Black
# 39                                      Like a Virgin
# 38                                           Tapestry
# 47                                    Whitney Houston
# ...

# %% [markdown]
#  * Создайте новый фрейм данных на основе набора данных hit_albums, который содержит только исполнителей, у которых в списке есть как минимум два альбома.

# %%
#Создадимновый датафрейм, в котором будут посчитано количество альбомов у каждого артиста


df2=hit_albums[['Artist','Album']]
df2=df2.groupby(['Artist'])['Album'].count().reset_index(name='Amount_of_albums')
df2=df2.loc[(df2['Amount_of_albums']>=2)]
df2
# Out:
#              Artist  Amount_of_albums
# 3             Adele                 2
# 6   Backstreet Boys                 2
# 9          Bon Jovi                 2
# 11   Britney Spears                 2
# 14      Celine Dion                 2
# 18           Eagles                 2
# 29          Madonna                 3
# 30     Mariah Carey                 2
# 33  Michael Jackson                 5
# 38       Pink Floyd                 2
# 43     Shania Twain                 3
# 48      The Beatles                 3
# 53  Various artists                 3
# 54  Whitney Houston                 2

# %%
#Условие я не совсем поняла, поэтому, на всякий случай, если необходима информация не только об исполнителях с более чем 2 альбомами,
#но и о самих альбомах, то вот:

hit_albums_2=pd.merge(hit_albums,df2,on='Artist',how='inner')
hit_albums_2[['Artist','Album','Amount_of_albums']].sort_values('Artist')
# Out:
#              Artist                                              Album  \
# 23            Adele                                                 25
# 22            Adele                                                 21
# 34  Backstreet Boys                                         Millennium
# 33  Backstreet Boys                Backstreet's Back / Backstreet Boys
# 28         Bon Jovi                                         Cross Road
# 27         Bon Jovi                                  Slippery When Wet
# 30   Britney Spears                            Oops!... I Did It Again
# 29   Britney Spears                              ...Baby One More Time
# 12      Celine Dion                                   Falling into You
# 13      Celine Dion                              Let's Talk About Love
# 7            Eagles                    Their Greatest Hits (1971–1975)
# 8            Eagles                                   Hotel California
# ...

# %% [markdown]
# * Создайте новый фрейм данных, содержащий общую сумму всех сертифицированных продаж за каждый год.

# %%
df3=hit_albums
df3=df3.groupby(['Released'])['Certified sales (millions)'].sum().reset_index(name='All Certified sales by year (millions)')
df3
# Out:
#     Released  All Certified sales by year (millions)
# 0       1967                                    13.1
# 1       1969                                    14.4
# 2       1970                                    25.0
# 3       1971                                    54.0
# 4       1973                                    22.7
# 5       1976                                    73.7
# 6       1977                                    67.5
# 7       1978                                    28.0
# 8       1979                                    57.6
# 9       1980                                    25.9
# 10      1981                                    25.0
# 11      1982                                    45.4
# 12      1983                                    62.0
# 13      1984                                   109.6
# 14      1985                                    67.7
# 15      1986                                    53.0
# 16      1987                                   144.5
# ...
